# %%
# list a= []
# tuple a=()

# dictionary  ( key-value pair)
person= {
    "name":"Aarohi",
    "ph":"9876543210",
    "city": "Delhi",   
}

# %%
print(person)
# Out:
# {'name': 'Aarohi', 'ph': '9876543210', 'city': 'Delhi'}

# %%
person["name"]
# Out:
# 'Aarohi'

# %%
person["ph"]
# Out:
# '9876543210'

# %%
person["ph"]="99999999"

# %%
print(person)
# Out:
# {'name': 'Aarohi', 'ph': '99999999', 'city': 'Delhi'}

# %%
person.pop("city")
# Out:
# 'Delhi'

# %%
print(person)
# Out:
# {'name': 'Aarohi', 'ph': '99999999'}

# %%
len(person)
# Out:
# 2

# %%
person["city_new"]="New Delhi"

# %%
print(person)
# Out:
# {'name': 'Aarohi', 'ph': '99999999', 'city_new': 'New Delhi'}

# %%
print(person.keys())
# Out:
# dict_keys(['name', 'ph', 'city_new'])

# %%
print(person.values())
# Out:
# dict_values(['Aarohi', '99999999', 'New Delhi'])

# %%
# response = {
#     "model": "gpt-4",
#     "tokens_used": 150,
#     "response_text": "Hello, how can I help you?"
# }
