# %%
print("hello")
# Out:
# hello

# %%
a=5  
b="This is the first class" 
c=0.01 
d=True

# %%
print(a)
# Out:
# 5

# %%
print(a,b,c,d)
# Out:
# 5 This is the first class 0.01 True

# %%
type(c)
# Out:
# float

# %%
type(a)
# Out:
# int

# %%
# variable never starts with number
1a=5
# Out:
#   Cell In[3], line 1
#     1a=5
#     ^
# SyntaxError: invalid decimal literal

# %%
a1=6

# %%
# no space between variable name
first vari= "rest"
# Out:
#   Cell In[5], line 1
#     first vari= "rest"
#           ^
# SyntaxError: invalid syntax

# %%
first_vari= "rest"

# %%
# no special characters sxcept _
@test=0.8
# Out:
#   Cell In[7], line 1
#     @test=0.8
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
# python is case sensitive
age=15
Age=17

# %%
name=input("Enter your name:")
# Out:
# Enter your name: Aarohi
