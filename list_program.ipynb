# %%
# list - you can store multiple datapoints , values, items
names = ["Aarohi", "Anu", "Zubin"]

# %%
numbers = [1,4,6,8,9]

mixed_data = ["Aarohi",1,0.9, True]

print(mixed_data)
# Out:
# ['Aarohi', 1, 0.9, True]

# %%
# indexing
mixed_data = ["Aarohi",1,0.9, True]
mixed_data[2]
# Out:
# 0.9

# %%
mixed_data[3]
# Out:
# True

# %%
mixed_data = ["Aarohi",1,0.9, True, 2.5, 67,34]
mixed_data[-1]
# Out:
# 34

# %%
len(mixed_data)
# Out:
# 7

# %%
mixed_data.append("Neha")

# %%
print(mixed_data)
# Out:
# ['Aarohi', 1, 0.9, True, 2.5, 67, 34, 'Neha']

# %%
mixed_data.remove(2.5)

# %%
mixed_data
# Out:
# ['Aarohi', 1, 0.9, True, 67, 34, 'Neha']

# %%
mixed_data[3]=False

# %%
print(mixed_data)
# Out:
# ['Aarohi', 1, 0.9, False, 67, 34, 'Neha']

# %%
numbers = [1,2,3,4]

# indentation

for num in numbers:
    print(num*2)
# Out:
# 2
# 4
# 6
# 8

# %%
for num in numbers:
    print(num*2)
# Out:
# 2
# 4
# 6
# 8

# %%
Assignemt-
1.	Create list of 5 numbers
2.	Print first and last element
3.	Add one number in the list.
4.	Calculate average

Once done - Comment : List Done
