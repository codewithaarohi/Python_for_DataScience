# %%
num = (1,2,3,4,5,6,7) # tuple
#num = [] # list

# %%
print(num)
# Out:
# (1, 2, 3, 4, 5, 6, 7)

# %%
# indexing
num[3]
# Out:
# 4

# %%
num[-1] # negative indexing
# Out:
# 7

# %%
num = (1,2,3,4,5,6,7)

# %%
num[1] = 33
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 num[1] = 33
#
# TypeError: 'tuple' object does not support item assignment

# %%
num = [1,2,3,4,5,6,7]

# %%
num[1] = 33

# %%
print(num)
# Out:
# [1, 33, 3, 4, 5, 6, 7]

# %%
num = (1,2,3,4,5,6,7)

# %%
len(num)
# Out:
# 7

# %%
week_days = ("Monday","Tuesday","Wednesday")

# %%
Assignment
1.	Create a tuple of 5 numbers
2.	Print first and last value
3.	Try modifying it and see error
4.	Create a list and modify it
Comment “TUPLE DONE” after practicing.
